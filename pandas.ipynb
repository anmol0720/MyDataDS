# %%
# !pwd
# Out:
# /home/nbuser/library

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/home/nbuser/library/telecom_churn.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
print(df.shape)
# Out:
# (3333, 20)

# %%
pd.set_option("display.max_row",100)
pd.set_option("display.max_column",100)
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.columns.tolist()
dtype={'State':int}

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
df.select_dtypes(include=['int64'])
# Out:
#       Account length  Area code  Number vmail messages  Total day calls  \
# 0                128        415                     25              110
# 1                107        415                     26              123
# 2                137        415                      0              114
# 3                 84        408                      0               71
# 4                 75        415                      0              113
# 5                118        510                      0               98
# 6                121        510                     24               88
# 7                147        415                      0               79
# 8                117        408                      0               97
# 9                141        415                     37               84
# 10                65        415                      0              137
# 11                74        415                      0              127
# ...

# %%
df1=df.copy()
df1.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df['Churn']=df['Churn'].astype('int64')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
df.describe(include=['int64','float64'])
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df['Total intl calls'].value_counts()
# Out:
# 3     668
# 4     619
# 2     489
# 5     472
# 6     336
# 7     218
# 1     160
# 8     116
# 9     109
# 10     50
# 11     28
# 0      18
# 12     15
# 13     14
# 15      7
# 14      6
# 18      3
# 16      2
# 19      1
# 17      1
# 20      1
# Name: Total intl calls, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %%
df.sort_values(by='Total intl calls',ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3291    MI             119        510                Yes             Yes
# 22      AZ             130        415                 No              No
# 982     ND              84        415                 No             Yes
# 2956    NM             112        415                 No              No
# 377     ND              79        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3291                     22              172.1              119
# 22                        0              183.0              112
# 982                      33              159.1              106
# 2956                      0               81.6               94
# 377                       0              205.7              123
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df['Churn'].mean()
# Out:
# 0.14491449144914492

# %%
df[df['Churn']==0].mean()
# Out:
# Account length            100.793684
# Area code                 437.074737
# Number vmail messages       8.604561
# Total day minutes         175.175754
# Total day calls           100.283158
# Total day charge           29.780421
# Total eve minutes         199.043298
# Total eve calls           100.038596
# Total eve charge           16.918909
# Total night minutes       200.133193
# Total night calls         100.058246
# Total night charge          9.006074
# Total intl minutes         10.158877
# Total intl calls            4.532982
# Total intl charge           2.743404
# Customer service calls      1.449825
# Churn                       0.000000
# dtype: float64

# %%
df[df['Churn']==1]['Total day minutes'].mean()
# Out:
# 206.91407867494814

# %%
df[(df['Churn']==0)&(df['International plan']=='No')]['Total intl minutes'].max()
# Out:
# 18.9

# %%
df.loc[0:5,'State':'Area code']
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %%
df.iloc[0:5,0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %%
df[:1]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
#
#    Customer service calls  Churn
# 0                       1  False

# %%
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes         395
# Total night calls           175
# Total night charge        17.77
# Total intl minutes           20
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                      True
# dtype: object

# %%
df[df['State'].apply(lambda State : State[0]=='W')].head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 9     WV             141        415                Yes             Yes
# 26    WY              57        408                 No             Yes
# 44    WI              64        510                 No              No
# 49    WY              97        415                 No             Yes
# 54    WY              87        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 9                      37              258.6               84
# 26                     39              213.0              115
# 44                      0              154.0               67
# 49                     24              133.2              135
# 54                      0              151.0               83
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 9              43.96              222.0              111             18.87
# ...

# %%
d={'No' :False,'Yes' :True}
df = df.replace({'Voice mail plan': d})
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False              NaN
# 1    OH             107        415               False              NaN
# 2    NJ             137        415               False              NaN
# 3    OH              84        408                True              NaN
# 4    OK              75        415                True              NaN
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
column_to_show=['State','Area code']
df.groupby(['Churn'])[column_to_show].head()
# Out:
#    State  Area code
# 0     KS        415
# 1     OH        415
# 2     NJ        415
# 3     OH        408
# 4     OK        415
# 10    IN        415
# 15    NY        415
# 21    CO        408
# 33    AZ        408
# 41    MD        408

# %%
df.groupby(['Churn'])[column_to_show].agg([np.mean,np.std,np.min,np.max])
# Out:
#         Area code
#              mean        std amin amax
# Churn
# False  437.074737  42.306156  408  510
# True   437.817805  42.792270  408  510

# %%
pd.crosstab(df['Churn'],df['International plan'],normalize=True)
# Out:
# International plan       No       Yes
# Churn
# False               0.79928  0.055806
# True                0.10381  0.041104

# %%
df.pivot_table(['Account length','International plan','Total day calls'],['Area code'],aggfunc='std')
# Out:
#            Account length  Total day calls
# Area code
# 408             40.393825        19.694243
# 415             39.256637        20.251354
# 510             40.381347        20.098565

# %%
df['TotalCalls']=df['Total day calls']+df['Total eve calls']+df['Total intl calls']
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes     ...      Total eve charge  \
# 0             45.07              197.4     ...                 16.78
# ...

# %%
df.drop([2,3],axis=0,inplace=True)
df.head()
# Out:
#    Account length  Area code International plan Voice mail plan  \
# 0             128        415                 No             Yes
# 1             107        415                 No             Yes
# 4              75        415                Yes              No
# 5             118        510                Yes              No
# 6             121        510                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 4                      0              166.7              113
# 5                      0              223.4               98
# 6                     24              218.2               88
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
pd.crosstab(df['Churn'],['International plan']).head()
sns.countplot(x='International plan',hue='Churn',data=df);

# %%
df = pd.DataFrame({ 'id': [1,2,3], 'c1':[0,0,np.nan], 'c2': [np.nan,1,1]})
df = df[['id', 'c1', 'c2']]
df['num_nulls'] = df[['c1', 'c2']].isnull().sum(axis=1)
df.head()
# Out:
#    id   c1   c2  num_nulls
# 0   1  0.0  NaN          1
# 1   2  0.0  1.0          0
# 2   3  NaN  1.0          1

# %%
df_filter = df['id'].isin([])
df[df_filter]
# Out:
# Empty DataFrame
# Columns: [id, c1, c2, num_nulls]
# Index: []

# %%
print(df.to_csv())
# Out:
# ,id,c1,c2,num_nulls
# 0,1,0.0,,1
# 1,2,0.0,1.0,0
# 2,3,,1.0,1

# %%
df['Customer service calls'].plot()

# %%
df['Customer service calls'].hist()

# %%
pd.plotting.scatter_matrix(df, figsize=(8,8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-187929dabaa9> in <module>
# ----> 1 pd.plotting.scatter_matrix(df, figsize=(8,8))
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/plotting/_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      77         values = df[a].values[mask[a].values]
#      78         rmin_, rmax_ = np.min(values), np.max(values)
# ---> 79         rdelta_ext = (rmax_ - rmin_) * range_padding / 2.
#      80         boundaries_list.append((rmin_ - rdelta_ext, rmax_ + rdelta_ext))
#      81
#
# TypeError: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
